# %% [markdown]
# # Lunar Lander Box2D lösning med PPO (Proximal Policy Optimization)
# -----
# #### Karim Kanji & Sebastian Fallström
# #### Preskriptiv Analytik, IA-20

# %%
# Pip Installs
# !pip install gymnasium
# !pip install stable_baselines3
# !pip install ufal.pybox2d
# !pip install tensorflow
# Out:
# Requirement already satisfied: gymnasium in c:\users\karim\anaconda3\lib\site-packages (0.29.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\karim\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\karim\anaconda3\lib\site-packages (from gymnasium) (4.11.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\karim\anaconda3\lib\site-packages (from gymnasium) (1.26.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\karim\anaconda3\lib\site-packages (from gymnasium) (4.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\karim\anaconda3\lib\site-packages (from gymnasium) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\karim\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.8.0)
# Requirement already satisfied: stable_baselines3 in c:\users\karim\anaconda3\lib\site-packages (2.2.1)
# Requirement already satisfied: matplotlib in c:\users\karim\anaconda3\lib\site-packages (from stable_baselines3) (3.5.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\karim\anaconda3\lib\site-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: torch>=1.13 in c:\users\karim\anaconda3\lib\site-packages (from stable_baselines3) (1.13.1)
# Requirement already satisfied: cloudpickle in c:\users\karim\anaconda3\lib\site-packages (from stable_baselines3) (2.0.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\karim\anaconda3\lib\site-packages (from stable_baselines3) (1.26.2)
# Requirement already satisfied: pandas in c:\users\karim\anaconda3\lib\site-packages (from stable_baselines3) (1.4.4)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\karim\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\karim\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.11.3)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\karim\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\karim\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\karim\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\karim\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\karim\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\karim\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\karim\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\karim\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\karim\anaconda3\lib\site-packages (from pandas->stable_baselines3) (2022.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\karim\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable_baselines3) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\karim\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: ufal.pybox2d in c:\users\karim\anaconda3\lib\site-packages (2.3.10.2)
# Requirement already satisfied: tensorflow in c:\users\karim\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.59.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.7.0)
# Requirement already satisfied: setuptools in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (63.4.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: packaging in c:\users\karim\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\karim\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\karim\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\karim\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\karim\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\karim\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\karim\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\karim\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.15.0->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\karim\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\karim\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\karim\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\karim\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\karim\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\karim\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\karim\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\karim\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\karim\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\karim\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)

# %%
import gymnasium as gym
# Skapa Gym omgivningen
env = gym.make("LunarLander-v2")

# %%
# Importerar PPO från SB3
# Källan användes för parametrarna och annan lånad kod
# Källa: https://huggingface.co/niftymark/ppo-LunarLander-v2 

from stable_baselines3 import PPO

# Definierar modellen
model = PPO(
    policy='MlpPolicy',
    env=env,
    n_steps=1024,
    batch_size=64,
    n_epochs=4,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Lär in modellen för 1000000 steg
model.learn(total_timesteps=1000000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.9     |
# |    ep_rew_mean     | -154     |
# | time/              |          |
# |    fps             | 1715     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87          |
# |    ep_rew_mean          | -188        |
# | time/                   |             |
# |    fps                  | 1424        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.001029172 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.0037     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.95e+03    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 5.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.9        |
# |    ep_rew_mean          | -168        |
# | time/                   |             |
# |    fps                  | 1386        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.000656996 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000325    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.54e+03    |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 8.55e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89           |
# |    ep_rew_mean          | -166         |
# | time/                   |              |
# |    fps                  | 1343         |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0008290705 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0335      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41e+03     |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 2.94e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.9         |
# |    ep_rew_mean          | -160         |
# | time/                   |              |
# |    fps                  | 1327         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0007680391 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00694     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+03     |
# |    n_updates            | 16           |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 88.9          |
# |    ep_rew_mean          | -161          |
# | time/                   |               |
# |    fps                  | 1315          |
# |    iterations           | 6             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00052276405 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00955      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.61e+03      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00125      |
# |    value_loss           | 3.18e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90.1          |
# |    ep_rew_mean          | -159          |
# | time/                   |               |
# |    fps                  | 1318          |
# |    iterations           | 7             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 0.00058669073 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00223      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.48e+03      |
# |    n_updates            | 24            |
# |    policy_gradient_loss | -0.00204      |
# |    value_loss           | 5.02e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90.3          |
# |    ep_rew_mean          | -151          |
# | time/                   |               |
# |    fps                  | 1311          |
# |    iterations           | 8             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00035431195 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.00526      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.39e+03      |
# |    n_updates            | 28            |
# |    policy_gradient_loss | -0.00111      |
# |    value_loss           | 2.94e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.8         |
# |    ep_rew_mean          | -154         |
# | time/                   |              |
# |    fps                  | 1285         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0036198688 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00855     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 571          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00632     |
# |    value_loss           | 1.42e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 93            |
# |    ep_rew_mean          | -152          |
# | time/                   |               |
# |    fps                  | 1258          |
# |    iterations           | 10            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00055345433 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | -0.00142      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.37e+03      |
# |    n_updates            | 36            |
# |    policy_gradient_loss | -0.00191      |
# |    value_loss           | 4.43e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94          |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 11          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.002016448 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.56e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00327    |
# |    value_loss           | 3.89e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.2         |
# |    ep_rew_mean          | -143         |
# | time/                   |              |
# |    fps                  | 1219         |
# |    iterations           | 12           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0014639883 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0479      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+03     |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 2.67e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.3        |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 1208        |
# |    iterations           | 13          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.002130983 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00133    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17e+03    |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00379    |
# |    value_loss           | 2.75e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.9         |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 14           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0003651231 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0291      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+03     |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00098     |
# |    value_loss           | 2.74e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.5         |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 1226         |
# |    iterations           | 15           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0021359378 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 3.97e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+03     |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 2.31e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 1235        |
# |    iterations           | 16          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005769457 |
# |    clip_fraction        | 0.000732    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00231    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 710         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00733    |
# |    value_loss           | 2.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 1242        |
# |    iterations           | 17          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.003924573 |
# |    clip_fraction        | 0.00781     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 2.25e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 851         |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.0035     |
# |    value_loss           | 1.85e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 1248         |
# |    iterations           | 18           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0018296337 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00358     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6e+03      |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 2.81e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -136         |
# | time/                   |              |
# |    fps                  | 1253         |
# |    iterations           | 19           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0020734738 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00292     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 697          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 1.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -131         |
# | time/                   |              |
# |    fps                  | 1259         |
# |    iterations           | 20           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0009563918 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.0127      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 690          |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 1.61e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 106          |
# |    ep_rew_mean          | -127         |
# | time/                   |              |
# |    fps                  | 1264         |
# |    iterations           | 21           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0038545767 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00158     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 638          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00398     |
# |    value_loss           | 1.16e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 22          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002858924 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000265   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 456         |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 1e+03       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | -112         |
# | time/                   |              |
# |    fps                  | 1272         |
# |    iterations           | 23           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0076415194 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00101     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 417          |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.00569     |
# |    value_loss           | 842          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | -108         |
# | time/                   |              |
# |    fps                  | 1276         |
# |    iterations           | 24           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0049868124 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | -0.00273     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 628          |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00169     |
# |    value_loss           | 1.16e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 1272        |
# |    iterations           | 25          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.003339581 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.000516   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 349         |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 609         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | -99.6        |
# | time/                   |              |
# |    fps                  | 1275         |
# |    iterations           | 26           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0015587106 |
# |    clip_fraction        | 0.000732     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.000679    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 288          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0036      |
# |    value_loss           | 524          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 102           |
# |    ep_rew_mean          | -95.6         |
# | time/                   |               |
# |    fps                  | 1275          |
# |    iterations           | 27            |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 0.00084239506 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | -0.00983      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 755           |
# |    n_updates            | 104           |
# |    policy_gradient_loss | -0.00127      |
# |    value_loss           | 1.58e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -91.3       |
# | time/                   |             |
# |    fps                  | 1278        |
# |    iterations           | 28          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.002395519 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.000696   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 209         |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 602         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -87.4       |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 29          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.007630052 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -0.000715   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 252         |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 461         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -85.1       |
# | time/                   |             |
# |    fps                  | 1279        |
# |    iterations           | 30          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009064468 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.000952   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 318         |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 933         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | -80.9        |
# | time/                   |              |
# |    fps                  | 1273         |
# |    iterations           | 31           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 8.881139e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.00862     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 514          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.000225     |
# |    value_loss           | 1.11e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -82.1       |
# | time/                   |             |
# |    fps                  | 1263        |
# |    iterations           | 32          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012324664 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -8.96e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 252         |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00979    |
# |    value_loss           | 501         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | -81.7        |
# | time/                   |              |
# |    fps                  | 1256         |
# |    iterations           | 33           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 33792        |
# | train/                  |              |
# |    approx_kl            | 0.0036376375 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.00682      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 357          |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 912          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 115           |
# |    ep_rew_mean          | -81.3         |
# | time/                   |               |
# |    fps                  | 1256          |
# |    iterations           | 34            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00024548883 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.3          |
# |    explained_variance   | 0.0335        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 982           |
# |    n_updates            | 132           |
# |    policy_gradient_loss | -0.000751     |
# |    value_loss           | 1.12e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -83         |
# | time/                   |             |
# |    fps                  | 1259        |
# |    iterations           | 35          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.004980077 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | -0.000507   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 240         |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 419         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 117           |
# |    ep_rew_mean          | -81.4         |
# | time/                   |               |
# |    fps                  | 1262          |
# |    iterations           | 36            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00056660094 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | -0.0406       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 318           |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.0016       |
# |    value_loss           | 889           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | -83.6        |
# | time/                   |              |
# |    fps                  | 1264         |
# |    iterations           | 37           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 37888        |
# | train/                  |              |
# |    approx_kl            | 0.0015029849 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -0.00332     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 296          |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 623          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 118           |
# |    ep_rew_mean          | -81.5         |
# | time/                   |               |
# |    fps                  | 1266          |
# |    iterations           | 38            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00052422454 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | -0.00132      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 649           |
# |    n_updates            | 148           |
# |    policy_gradient_loss | -0.00201      |
# |    value_loss           | 1.17e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -80.8       |
# | time/                   |             |
# |    fps                  | 1269        |
# |    iterations           | 39          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.011929994 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.00126     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 266         |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 578         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 123           |
# |    ep_rew_mean          | -80.6         |
# | time/                   |               |
# |    fps                  | 1271          |
# |    iterations           | 40            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00036540028 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.26         |
# |    explained_variance   | -0.0268       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 692           |
# |    n_updates            | 156           |
# |    policy_gradient_loss | -0.000822     |
# |    value_loss           | 1.15e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | -77.4        |
# | time/                   |              |
# |    fps                  | 1273         |
# |    iterations           | 41           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0012555704 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00671      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 520          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 574          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | -80.9        |
# | time/                   |              |
# |    fps                  | 1275         |
# |    iterations           | 42           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0011740499 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 0.0146       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 153          |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 330          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 129           |
# |    ep_rew_mean          | -79.5         |
# | time/                   |               |
# |    fps                  | 1277          |
# |    iterations           | 43            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 44032         |
# | train/                  |               |
# |    approx_kl            | 0.00011343538 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.26         |
# |    explained_variance   | -0.0187       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 517           |
# |    n_updates            | 168           |
# |    policy_gradient_loss | 0.000464      |
# |    value_loss           | 799           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 120           |
# |    ep_rew_mean          | -81.9         |
# | time/                   |               |
# |    fps                  | 1278          |
# |    iterations           | 44            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00087184674 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.27         |
# |    explained_variance   | -0.00458      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 209           |
# |    n_updates            | 172           |
# |    policy_gradient_loss | -0.00199      |
# |    value_loss           | 497           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 120           |
# |    ep_rew_mean          | -77.9         |
# | time/                   |               |
# |    fps                  | 1280          |
# |    iterations           | 45            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 46080         |
# | train/                  |               |
# |    approx_kl            | 0.00017717225 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.29         |
# |    explained_variance   | -0.000362     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 404           |
# |    n_updates            | 176           |
# |    policy_gradient_loss | -0.000657     |
# |    value_loss           | 599           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | -74         |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 46          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015321307 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.000256   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 217         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 435         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 47          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.009084627 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.000151   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 231         |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 462         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 121           |
# |    ep_rew_mean          | -66.4         |
# | time/                   |               |
# |    fps                  | 1285          |
# |    iterations           | 48            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00019265676 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.21         |
# |    explained_variance   | -0.000265     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 319           |
# |    n_updates            | 188           |
# |    policy_gradient_loss | -0.00056      |
# |    value_loss           | 571           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | -58.3        |
# | time/                   |              |
# |    fps                  | 1287         |
# |    iterations           | 49           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 50176        |
# | train/                  |              |
# |    approx_kl            | 0.0006557957 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | -0.00103     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 208          |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 432          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 119           |
# |    ep_rew_mean          | -54           |
# | time/                   |               |
# |    fps                  | 1289          |
# |    iterations           | 50            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00029299315 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.21         |
# |    explained_variance   | -0.00104      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 259           |
# |    n_updates            | 196           |
# |    policy_gradient_loss | -0.00163      |
# |    value_loss           | 501           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | -53.1       |
# | time/                   |             |
# |    fps                  | 1285        |
# |    iterations           | 51          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.004533755 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -0.00217    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 897         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 1.43e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | -53.3        |
# | time/                   |              |
# |    fps                  | 1279         |
# |    iterations           | 52           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0006480489 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | -0.0032      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 914          |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000176    |
# |    value_loss           | 1.6e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 53          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.004992555 |
# |    clip_fraction        | 0.00732     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | -0.00298    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 544         |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 1.22e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 133          |
# |    ep_rew_mean          | -53.1        |
# | time/                   |              |
# |    fps                  | 1275         |
# |    iterations           | 54           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0056897067 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.000279    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 137          |
# |    n_updates            | 212          |
# ...
# |    iterations           | 960          |
# |    time_elapsed         | 887          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0012780866 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.66        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.3         |
# |    n_updates            | 3836         |
# |    policy_gradient_loss | -0.000991    |
# |    value_loss           | 83.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 371         |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 961         |
# |    time_elapsed         | 888         |
# |    total_timesteps      | 984064      |
# | train/                  |             |
# |    approx_kl            | 0.001463241 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 125         |
# |    n_updates            | 3840        |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 418         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 371           |
# |    ep_rew_mean          | 221           |
# | time/                   |               |
# |    fps                  | 1106          |
# |    iterations           | 962           |
# |    time_elapsed         | 890           |
# |    total_timesteps      | 985088        |
# | train/                  |               |
# |    approx_kl            | 0.00022446417 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.772        |
# |    explained_variance   | 0.675         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 592           |
# |    n_updates            | 3844          |
# |    policy_gradient_loss | -0.000284     |
# |    value_loss           | 1.64e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 365           |
# |    ep_rew_mean          | 223           |
# | time/                   |               |
# |    fps                  | 1106          |
# |    iterations           | 963           |
# |    time_elapsed         | 891           |
# |    total_timesteps      | 986112        |
# | train/                  |               |
# |    approx_kl            | 0.00021533965 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.77         |
# |    explained_variance   | 0.881         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 240           |
# |    n_updates            | 3848          |
# |    policy_gradient_loss | -0.000628     |
# |    value_loss           | 314           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 364           |
# |    ep_rew_mean          | 218           |
# | time/                   |               |
# |    fps                  | 1106          |
# |    iterations           | 964           |
# |    time_elapsed         | 892           |
# |    total_timesteps      | 987136        |
# | train/                  |               |
# |    approx_kl            | 0.00077311776 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.708        |
# |    explained_variance   | 0.888         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 70.9          |
# |    n_updates            | 3852          |
# |    policy_gradient_loss | -0.000814     |
# |    value_loss           | 344           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 357         |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 965         |
# |    time_elapsed         | 893         |
# |    total_timesteps      | 988160      |
# | train/                  |             |
# |    approx_kl            | 0.000252851 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.3        |
# |    n_updates            | 3856        |
# |    policy_gradient_loss | 4.04e-06    |
# |    value_loss           | 1.28e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 357           |
# |    ep_rew_mean          | 214           |
# | time/                   |               |
# |    fps                  | 1106          |
# |    iterations           | 966           |
# |    time_elapsed         | 894           |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 8.8354165e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.777        |
# |    explained_variance   | 0.799         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 429           |
# |    n_updates            | 3860          |
# |    policy_gradient_loss | -0.000274     |
# |    value_loss           | 974           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 353          |
# |    ep_rew_mean          | 216          |
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 967          |
# |    time_elapsed         | 894          |
# |    total_timesteps      | 990208       |
# | train/                  |              |
# |    approx_kl            | 7.615861e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.776       |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 350          |
# |    n_updates            | 3864         |
# |    policy_gradient_loss | -4.27e-05    |
# |    value_loss           | 697          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 968          |
# |    time_elapsed         | 895          |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0001350122 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.723       |
# |    explained_variance   | 0.645        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 3868         |
# |    policy_gradient_loss | -0.000327    |
# |    value_loss           | 376          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 969         |
# |    time_elapsed         | 896         |
# |    total_timesteps      | 992256      |
# | train/                  |             |
# |    approx_kl            | 0.006960761 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 341         |
# |    n_updates            | 3872        |
# |    policy_gradient_loss | -0.00235    |
# |    value_loss           | 404         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 970         |
# |    time_elapsed         | 897         |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.001355611 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 3876        |
# |    policy_gradient_loss | -0.000673   |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 359         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 971         |
# |    time_elapsed         | 898         |
# |    total_timesteps      | 994304      |
# | train/                  |             |
# |    approx_kl            | 0.012485651 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.698      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.6         |
# |    n_updates            | 3880        |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 27.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 361          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 972          |
# |    time_elapsed         | 899          |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0007986308 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.672       |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27           |
# |    n_updates            | 3884         |
# |    policy_gradient_loss | 0.000563     |
# |    value_loss           | 160          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 361          |
# |    ep_rew_mean          | 221          |
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 973          |
# |    time_elapsed         | 900          |
# |    total_timesteps      | 996352       |
# | train/                  |              |
# |    approx_kl            | 0.0020354188 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.1         |
# |    n_updates            | 3888         |
# |    policy_gradient_loss | -0.000257    |
# |    value_loss           | 64           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 357          |
# |    ep_rew_mean          | 217          |
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 974          |
# |    time_elapsed         | 901          |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0012242235 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.737       |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.66         |
# |    n_updates            | 3892         |
# |    policy_gradient_loss | -0.000381    |
# |    value_loss           | 53.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 355           |
# |    ep_rew_mean          | 220           |
# | time/                   |               |
# |    fps                  | 1106          |
# |    iterations           | 975           |
# |    time_elapsed         | 902           |
# |    total_timesteps      | 998400        |
# | train/                  |               |
# |    approx_kl            | 0.00066852826 |
# |    clip_fraction        | 0.000244      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.624        |
# |    explained_variance   | 0.405         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 854           |
# |    n_updates            | 3896          |
# |    policy_gradient_loss | -0.000717     |
# |    value_loss           | 1.2e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 353          |
# |    ep_rew_mean          | 218          |
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 976          |
# |    time_elapsed         | 903          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0041679256 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.18         |
# |    n_updates            | 3900         |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 30.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 354         |
# |    ep_rew_mean          | 220         |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 977         |
# |    time_elapsed         | 904         |
# |    total_timesteps      | 1000448     |
# | train/                  |             |
# |    approx_kl            | 0.004918359 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 640         |
# |    n_updates            | 3904        |
# |    policy_gradient_loss | -5.44e-05   |
# |    value_loss           | 991         |
# -----------------------------------------

# %%
# Sparar modellen med x namn
model_name = "run3"
model.save(model_name)

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
import gymnasium as gym
import numpy as np
import random
from collections import deque

# Navigera till modellen
path = "C:/Users/karim/Documents/Skola/Preskriptiv analytik/run3.zip"
model = PPO.load(path)

# Kör ny omgivning
eval_env = gym.make("LunarLander-v2", render_mode="human")
obs = eval_env.reset()

done = False
while not done:
    observation = obs if isinstance(obs, np.ndarray) else obs[0]
    action, _states = model.predict(observation, deterministic=True)
    
    obs, rewards, done, info, *additional_info = eval_env.step(action)
    eval_env.render()
# Stäng omgivningen
eval_env.close()

# %%
from stable_baselines3.common.env_util import make_vec_env

# Icke rendered omgivning
eval_env = make_vec_env('LunarLander-v2', n_envs=1)


try:
    # Evaluering
    mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=100, deterministic=True)
    print(f"Mean Reward: {mean_reward}, Std Reward: {std_reward}")
except Exception as e:
    print(f"An error occurred during evaluation: {e}")
# Out:
# Mean Reward: 256.94645629999997, Std Reward: 23.868989568029615

# %% [markdown]
# ## Rapport om Användning av PPO-Metoden för Lunar Lander
#
# #### Inledning
# I detta projekt har vi använt Proximal Policy Optimization (PPO), en populär metod inom förstärkningsinlärning, för att träna en agent att utföra uppgifter i Lunar Lander-miljön. PPO är känd för sin effektivitet och balans mellan utforskning och exploatering.
#
# #### Metod
# PPO-metoden utnyttjar MlpPolicy (definierat i början av koden, står för Multi-Layer Perceptron) för att optimera agentens beslutsfattande process. I vårt fall är målet för agenten att framgångsrikt landa en rymdfarkost på en angiven plats.
#
# #### Träningsresultat
# Efter träningen har agenten utvärderats över 1,000,000 steg. De statistiska resultaten är följande:
#
# Genomsnittlig belöning (Mean Reward): 257.308 <br>
# Standardavvikelse för belöning (Std Reward): 21.6988
#
# Dessa resultat indikerar en hög prestanda och pålitlighet hos agenten. En genomsnittlig belöning över 250 pekar på att agenten konsekvent kan landa rymdfarkosten på ett säkert och effektivt sätt. Standardavvikelsen, som är relativt låg, visar på att agentens prestation är jämn och förutsägbar över olika episoder.
#
# #### Slutsats
# Användningen av PPO-metoden i detta projekt har visat sig vara framgångsrik. Agenten har lärt sig att effektivt hantera de utmaningar som Lunar Lander-miljön erbjuder, vilket resulterar i höga och konsekventa belöningar. Denna framgång understryker PPO-metodens styrka i att hantera komplexa uppgifter inom förstärkningsinlärning.

# %% [markdown]
# #### Källor
#
# OpenAI. (2023). Svar på fråga om bl.a. ["Proximal Policy Optimization and Multi-Layer Perceptron in Reinforcement Learning"]. ChatGPT verion 4/3.5.
# <br><br>
# niftymark. (u.å.). ppo-LunarLander-v2. Hugging Face. Hämtad 4 december 2023, från https://huggingface.co/niftymark/ppo-LunarLander-v2
# <br><br>
# Rem4rkable. (u.å.). Solving-the-LunarLanderContinuous-v2. GitHub. Hämtad 4 december 2023, från https://github.com/Rem4rkable/Solving-the-LunarLanderContinuous-v2/blob/main/RL_Project_notebook.ipynb
# <br><br>
# Farama Foundation. (u.å.). Lunar Lander. Gymnasium by Farama. Hämtad 4 december 2023, från https://gymnasium.farama.org/environments/box2d/lunar_lander/
